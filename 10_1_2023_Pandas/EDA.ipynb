# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe() # numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.386083    2.308642   29.699118    0.523008
# std     257.353842    0.487123    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Survived"].value_counts()
# Out:
# 0    547
# 1    344
# Name: Survived, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df["Survived"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df["Survived"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ## 5.astype

# %%
# info()
#df.dtypes
df["Survived"].dtype
# Out:
# dtype('int64')

# %%
df["Survived"].astype("str").dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df.shape[0] # row count
# Out:
# 891

# %%
df.shape[1] # column count
# Out:
# 12

# %% [markdown]
# ## check null values

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name  Gender    Age  SibSp  Parch  \
# 0          False     False   False  False   False  False  False  False
# 1          False     False   False  False   False  False  False  False
# 2          False     False   False  False   False  False  False  False
# 3          False     False   False  False   False  False  False  False
# 4          False     False   False  False   False  False  False  False
# ..           ...       ...     ...    ...     ...    ...    ...    ...
# 886        False     False   False  False   False  False  False  False
# 887        False     False   False  False   False  False  False  False
# 888        False     False   False  False   False   True  False  False
# 889        False     False   False  False   False  False  False  False
# 890        False     False   False  False   False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# 0     False  False   True     False
# 1     False  False  False     False
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  Gender    Age  SibSp  Parch  \
# 0          False     False   False  False   False  False  False  False
# 1          False     False   False  False   False  False  False  False
# 2          False     False   False  False   False  False  False  False
# 3          False     False   False  False   False  False  False  False
# 4          False     False   False  False   False  False  False  False
# ..           ...       ...     ...    ...     ...    ...    ...    ...
# 886        False     False   False  False   False  False  False  False
# 887        False     False   False  False   False  False  False  False
# 888        False     False   False  False   False   True  False  False
# 889        False     False   False  False   False  False  False  False
# 890        False     False   False  False   False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# 0     False  False   True     False
# 1     False  False  False     False
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().mean()*100 # per of missing values
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Gender          0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
(df.isna().sum())/((df.shape[0]))*100  # per of missing values
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Gender          0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Access DataFrame data

# %%
x = df[["Survived","Age","Cabin","Fare"]]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x
# Out:
#      Survived   Age Cabin     Fare
# 0           0  22.0   NaN   7.2500
# 1           1  38.0   C85  71.2833
# 2           1  26.0   NaN   7.9250
# 3           1  35.0  C123  53.1000
# 4           0  35.0   NaN   8.0500
# ..        ...   ...   ...      ...
# 886         0  27.0   NaN  13.0000
# 887         1  19.0   B42  30.0000
# 888         0   NaN   NaN  23.4500
# 889         1  26.0  C148  30.0000
# 890         0  32.0   NaN   7.7500
#
# [891 rows x 4 columns]

# %% [markdown]
# ## Slicing

# %%
import numpy as np
df = pd.DataFrame(np.random.randint(10,100,size=(12,5)))
df
# Out:
#      0   1   2   3   4
# 0   64  47  39  82  37
# 1   40  56  55  43  97
# 2   66  30  57  94  22
# 3   86  43  38  65  90
# 4   57  21  75  42  88
# 5   17  73  18  21  49
# 6   71  85  80  71  16
# 7   67  32  82  96  31
# 8   77  23  85  31  11
# 9   80  53  10  28  54
# 10  53  80  64  97  54
# 11  77  33  79  27  57

# %%
df.head()
# Out:
#     0   1   2   3   4
# 0  64  47  39  82  37
# 1  40  56  55  43  97
# 2  66  30  57  94  22
# 3  86  43  38  65  90
# 4  57  21  75  42  88

# %%
df.tail()
# Out:
#      0   1   2   3   4
# 7   67  32  82  96  31
# 8   77  23  85  31  11
# 9   80  53  10  28  54
# 10  53  80  64  97  54
# 11  77  33  79  27  57

# %%
df.sample()
# Out:
#     0   1   2   3   4
# 1  40  56  55  43  97

# %%
df
# Out:
#      0   1   2   3   4
# 0   64  47  39  82  37
# 1   40  56  55  43  97
# 2   66  30  57  94  22
# 3   86  43  38  65  90
# 4   57  21  75  42  88
# 5   17  73  18  21  49
# 6   71  85  80  71  16
# 7   67  32  82  96  31
# 8   77  23  85  31  11
# 9   80  53  10  28  54
# 10  53  80  64  97  54
# 11  77  33  79  27  57

# %%
df.head(4) # df[:4]
# Out:
#     0   1   2   3   4
# 0  64  47  39  82  37
# 1  40  56  55  43  97
# 2  66  30  57  94  22
# 3  86  43  38  65  90

# %%
df[:4]
# Out:
#     0   1   2   3   4
# 0  64  47  39  82  37
# 1  40  56  55  43  97
# 2  66  30  57  94  22
# 3  86  43  38  65  90

# %%
df[[1,4]][:4]
# Out:
#     1   4
# 0  47  37
# 1  56  97
# 2  30  22
# 3  43  90

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[["Gender","Survived"]][1:3]
# Out:
#    Gender  Survived
# 1  female         1
# 2  female         1

# %%
df[["Gender","Survived"]][::2]
# Out:
#      Gender  Survived
# 0      male         0
# 2    female         1
# 4      male         0
# 6      male         0
# 8    female         1
# ..      ...       ...
# 882  female         0
# 884    male         0
# 886    male         0
# 888  female         0
# 890    male         0
#
# [446 rows x 2 columns]

# %%
loc & iloc
